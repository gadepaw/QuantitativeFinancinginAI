# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras import layers

# %%
final_df = pd.read_csv("../data/final_features_with_targets.csv", parse_dates=['Date'], index_col='Date')

asset = 'Nikkei225'

feature_cols = [col for col in final_df.columns if not col.endswith('_target_5d')]
target_cols = [col for col in final_df.columns if col.endswith('_target_5d')]

X_asset = final_df[[col for col in final_df.columns if col.startswith(asset) and not col.endswith('_target_5d')]]
y_asset = final_df[f"{asset}_target_5d"]

X_asset, y_asset = X_asset.dropna(), y_asset.dropna()
X_asset, y_asset = X_asset.align(y_asset, join='inner', axis=0)

# %%
split_idx = int(len(X_asset) * 0.8)
X_train, X_val = X_asset[:split_idx], X_asset[split_idx:]
y_train, y_val = y_asset[:split_idx], y_asset[split_idx:]

# %%
def build_model(hp):
    model = keras.Sequential()
    
    # Input layer
    model.add(layers.Input(shape=(X_asset.shape[1],)))

    # Tune number of hidden layers: 1 to 3
    for i in range(hp.Int("num_layers", 1, 3)):
        model.add(layers.Dense(
            units=hp.Int(f"units_{i}", min_value=32, max_value=256, step=32),
            activation=hp.Choice("activation", ["relu", "tanh"])
        ))
    
    # Output layer
    model.add(layers.Dense(1, activation='linear'))
    
    # Tune optimizer and learning rate
    optimizer = hp.Choice("optimizer", ["adam", "rmsprop", "sgd"])
    model.compile(
        optimizer=optimizer,
        loss='mse',
        metrics=['mae']
    )
    
    return model

# %%
tuner = kt.RandomSearch(
    build_model,                 # function previously created 
    objective='val_loss',        # Minimize validation loss
    max_trials=10,               #  different combinations
    executions_per_trial=2,      # Train each model twice and average the results
    directory='kt_mlp_tuning_new',   # Folder to save search results
    project_name= f"{asset}_MLP",
    seed = 42 
)

tuner.search(X_train, y_train, epochs=50, validation_split=0.2, verbose=1)
# Out:
# Trial 10 Complete [00h 02m 15s]
# val_loss: 0.00020370430866023526
#
# Best val_loss So Far: 0.00019472564599709585
# Total elapsed time: 00h 20m 36s

# %%
best_hp = tuner.get_best_hyperparameters(1)[0]

model = build_model(best_hp)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
verbose=1
)
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.2849 - mae: 0.3554 - val_loss: 5.7668e-04 - val_mae: 0.0207
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.7057e-04 - mae: 0.0127 - val_loss: 2.0809e-04 - val_mae: 0.0103
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.9567e-04 - mae: 0.0101 - val_loss: 1.9790e-04 - val_mae: 0.0098
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.8342e-04 - mae: 0.0097 - val_loss: 1.9493e-04 - val_mae: 0.0097
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.8095e-04 - mae: 0.0097 - val_loss: 1.9500e-04 - val_mae: 0.0098
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.0517e-04 - mae: 0.0102 - val_loss: 2.0369e-04 - val_mae: 0.0101
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.9775e-04 - mae: 0.0103 - val_loss: 2.0040e-04 - val_mae: 0.0100
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.8139e-04 - mae: 0.0097 - val_loss: 1.9927e-04 - val_mae: 0.0099
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1
100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.3098e-04 - mae: 0.0114 - val_loss: 2.2744e-04 - val_mae: 0.0112
# Epoch 62/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.2733e-04 - mae: 0.0111 - val_loss: 1.9286e-04 - val_mae: 0.0097
# Epoch 63/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.2308e-04 - mae: 0.0109 - val_loss: 1.9773e-04 - val_mae: 0.0099
# Epoch 64/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.8443e-04 - mae: 0.0100 - val_loss: 2.3641e-04 - val_mae: 0.0115
# Epoch 65/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.8797e-04 - mae: 0.0129 - val_loss: 2.2074e-04 - val_mae: 0.0108
# Epoch 66/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.0945e-04 - mae: 0.0108 - val_loss: 1.9440e-04 - val_mae: 0.0098
# Epoch 67/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.4520e-04 - mae: 0.0118 - val_loss: 2.6726e-04 - val_mae: 0.0127
# Epoch 68/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.1645e-04 - mae: 0.0109 - val_loss: 1.9322e-04 - val_mae: 0.0097
# Epoch 69/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.9721e-04 - mae: 0.0104 - val_loss: 3.0955e-04 - val_mae: 0.0142
# Epoch 70/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.6419e-04 - mae: 0.0121 - val_loss: 2.0532e-04 - val_mae: 0.0102
# Epoch 71/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.0809e-04 - mae: 0.0107 - val_loss: 1.9535e-04 - val_mae: 0.0098
# Epoch 72/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.3402e-04 - mae: 0.0113 - val_loss: 2.0450e-04 - val_mae: 0.0102
# Epoch 73/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.2761e-04 - mae: 0.0110 - val_loss: 2.0305e-04 - val_mae: 0.0102
# Epoch 74/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.1715e-04 - mae: 0.0110 - val_loss: 1.8993e-04 - val_mae: 0.0097
# Epoch 75/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.2494e-04 - mae: 0.0106 - val_loss: 1.9203e-04 - val_mae: 0.0098
# Epoch 76/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.3180e-04 - mae: 0.0113 - val_loss: 1.9051e-04 - val_mae: 0.0097
# Epoch 77/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.1830e-04 - mae: 0.0108 - val_loss: 1.8976e-04 - val_mae: 0.0097
# Epoch 78/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.2729e-04 - mae: 0.0113 - val_loss: 1.8955e-04 - val_mae: 0.0097
# Epoch 79/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.9979e-04 - mae: 0.0102 - val_loss: 1.8943e-04 - val_mae: 0.0097
# Epoch 80/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.1056e-04 - mae: 0.0108 - val_loss: 2.0200e-04 - val_mae: 0.0102
# Epoch 81/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.9406e-04 - mae: 0.0103 - val_loss: 2.4502e-04 - val_mae: 0.0118
# Epoch 82/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.3836e-04 - mae: 0.0109 - val_loss: 2.0024e-04 - val_mae: 0.0101
# Epoch 83/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.9099e-04 - mae: 0.0101 - val_loss: 2.1742e-04 - val_mae: 0.0108
# Epoch 84/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.0196e-04 - mae: 0.0107 - val_loss: 2.5777e-04 - val_mae: 0.0123
# Epoch 85/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.2577e-04 - mae: 0.0111 - val_loss: 2.5462e-04 - val_mae: 0.0122
# Epoch 86/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.2979e-04 - mae: 0.0113 - val_loss: 2.6581e-04 - val_mae: 0.0126
# Epoch 87/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.0708e-04 - mae: 0.0107 - val_loss: 1.9998e-04 - val_mae: 0.0101
# Epoch 88/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.8949e-04 - mae: 0.0101 - val_loss: 1.9039e-04 - val_mae: 0.0097
# Epoch 89/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.9798e-04 - mae: 0.0104 - val_loss: 1.8967e-04 - val_mae: 0.0097
# Epoch 90/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.4351e-04 - mae: 0.0115 - val_loss: 1.9166e-04 - val_mae: 0.0098
# Epoch 91/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.0161e-04 - mae: 0.0103 - val_loss: 2.1484e-04 - val_mae: 0.0107
# Epoch 92/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.1341e-04 - mae: 0.0110 - val_loss: 1.9628e-04 - val_mae: 0.0100
# Epoch 93/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.1136e-04 - mae: 0.0106 - val_loss: 1.9478e-04 - val_mae: 0.0099
# Epoch 94/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9599e-04 - mae: 0.0102 - val_loss: 2.2958e-04 - val_mae: 0.0113
# Epoch 95/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0207e-04 - mae: 0.0105 - val_loss: 3.1173e-04 - val_mae: 0.0142
# Epoch 96/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3088e-04 - mae: 0.0117 - val_loss: 1.9206e-04 - val_mae: 0.0098
# Epoch 97/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2752e-04 - mae: 0.0112 - val_loss: 2.0411e-04 - val_mae: 0.0103
# Epoch 98/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0823e-04 - mae: 0.0108 - val_loss: 1.8816e-04 - val_mae: 0.0096
# Epoch 99/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1895e-04 - mae: 0.0107 - val_loss: 3.0615e-04 - val_mae: 0.0140
# Epoch 100/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1735e-04 - mae: 0.0109 - val_loss: 3.3265e-04 - val_mae: 0.0147

# %%
y_pred = model.predict(X_val)
#Evaluation 

rmse = np.sqrt(mean_squared_error(y_val, y_pred))
mae = mean_absolute_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)

print(f"RMSE: {rmse:.5f}")
print(f"MAE : {mae:.5f}")
print(f"R²  : {r2:.5f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RMSE: 0.01826
# MAE : 0.01423
# R²  : -0.75725

# %%
predictions_df = pd.DataFrame({
    'Date': y_val.index,
    'y_true': y_val.values.flatten(),
    'y_pred': y_pred.flatten()
})

predictions_df.to_csv(f"../results/{asset}_mlp_predictions.csv", index=False)
print(f" Predictions saved to ../results/{asset}_mlp_predictions.csv")
# Out:
#  Predictions saved to ../results/Nikkei225_mlp_predictions.csv

# %%
#print(y_asset.describe())
#y_asset.plot(title="Target Distribution")

#print(X_asset.describe())
import seaborn as sns
#sns.heatmap(X_asset.corr(), cmap='coolwarm')

#print(np.unique(y_pred))  # If it's just one or two values, it's flat
#X_asset.describe().T[['mean', 'std', 'min', 'max']]
#y_asset.describe()
#y_asset.plot()
print(X_train.shape, y_train.shape)
# Out:
# (2759, 6) (2759,)

# %%
plt.figure(figsize=(12, 6))
plt.plot(predictions_df['Date'], predictions_df['y_true'], label='Actual', linewidth=2)
plt.plot(predictions_df['Date'], predictions_df['y_pred'], label='Predicted', linestyle='--')
plt.title(f'MLP Prediction vs Actual for {asset}')
plt.xlabel('Date')
plt.ylabel('5-Day Log Return')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
